# %% [markdown]
# # Recommendation Systems - Lab
#
# ## Introduction
#
# Now that you've gotten an introduction to collaborative filtering and recommendation systems, it's time to put your skills to test and attempt to build a recommendation system for a real world dataset! For this exercise, you'll be using a dataset regarding the book reviews on the Amazon marketplace. While the previous lesson focused on user-based recommendation systems, you'll apply a parallel process for an item-based recommendation system to recommend similar books at the bottom of the product page.
#
# ## Objectives
#
# You will be able to:
# * Implement a recommendation system on a real world dataset

# %% [markdown]
# ## Load the Dataset
#
# To start, load the dataset stored in the file `'books_data.edgelist'`.

# %%
import pandas as pd

# %%
books = pd.read_csv('books_data.edgelist', names=['source', 'target', 'weight'], delimiter=' ')

# %%
books.head()
# Out:
#        source      target  weight
# 0  0827229534  0804215715     0.7
# 1  0827229534  156101074X     0.5
# 2  0827229534  0687023955     0.8
# 3  0827229534  0687074231     0.8
# 4  0827229534  082721619X     0.7

# %% [markdown]
# ## Load the MetaData
#
# Next, load the metadata associated with each of the books being reviewed. The metadata is stored in the file `'books_meta.txt'`.

# %%
meta_books = pd.read_csv('books_meta.txt', index_col='Id', sep='\t')
meta_books.head()
# Out:
#               ASIN                                              Title  \
# Id
# 1       0827229534            Patterns of Preaching: A Sermon Sampler
# 2       0738700797                         Candlemas: Feast of Flames
# 3       0486287785   World War II Allied Fighter Planes Trading Cards
# 4       0842328327  Life Application Bible Commentary: 1 and 2 Tim...
# 5       1577943082    Prayers That Avail Much for Business: Executive
# 6       0486220125  How the Other Half Lives: Studies Among the Te...
# 8       0231118597                                Losing Matt Shepard
# 9       1859677800  Making Bread: The Taste of Traditional Home-Ba...
# 10      0375709363                             The Edward Said Reader
# 11      0871318237  Resetting the Clock : Five Anti-Aging Hormones...
# 12      1590770218  Fantastic Food with Splenda : 160 Great Recipe...
# 13      0313230269  Clockwork Worlds : Mechanized Environments in ...
# 15      1559362022                       Wake Up and Smell the Coffee
# 16      0195110382        War at Sea: A Naval History of World War II
# 17      0849311012                 Telecommunications Cost Management
# 19      078510870X                            Ultimate Marvel Team-Up
# 20      3895780812  Computed Tomography : Fundamentals, System Tec...
# 23      0393049388                              Strange Fire: A Novel
# 24      0553525476  The Casebook of Sherlock Holmes, Volume 2 (Cas...
# 25      0939165252    Jailed for Freedom: American Women Win the Vote
# 26      1590930509                                     Chicken Little
# 27      0231096704           The Columbia Anthology of Gay Literature
# 28      1893732290  God Knows Marriage Isn't Always Easy: 12 Ways ...
# 29      0781718791  Advanced Pediatric Clinical Assessment: Skills...
# 30      0471150274              Solving Statics Problems with MathCAD
# 31      0895872218  Backroad Buffets & Country Cafes: A Southern G...
# 32      0761116982                       Staff Meals from Chanterelle
# 33      0439240751                     Double Jeopardy (T*Witches, 6)
# 35      0618111212                    Burnt Toast on Davenport Street
# 36      1898630038             Uists & Barra (Pevensey Island guides)
# ...            ...                                                ...
# 548502  1579545122  Cut the Clutter and Stow the Stuff : The Q.U.I...
# 548503  0486681033        A History and Philosophy of Fluid Mechanics
# 548510            11        5.0                24             0.72
# 548511             6        4.5                 5             0.00
# 548512             1        5.0                 0             0.00
# 548513             2        5.0                 0             0.00
# 548514             3        5.0                 4             1.00
# 548515             1        5.0                 1             0.00
# 548516             2        4.0                 0             0.00
# 548517            10        5.0                 0             0.00
# 548518            15        5.0                 4             0.43
# 548519             1        5.0                 3             1.00
# 548520             7        4.5                 7             0.51
# 548521             1        5.0                 6             0.74
# 548522             1        5.0                 6             0.92
# 548523             9        4.5                 0             0.00
# 548524             6        5.0                 2             0.00
# 548525             1        4.0                 0             0.00
# 548527             3        4.5                 0             0.00
# 548528            16        4.5                 0             0.00
# 548529             1        5.0                 5             0.55
# 548530             4        4.5                 2             0.00
# 548531             5        5.0                 4             0.87
# 548532            15        4.0                 0             0.00
# 548533             1        4.0                 0             0.00
# 548534             2        4.5                 3             0.58
#
# [393551 rows x 9 columns]

# %% [markdown]
# ## Create an Item Matrix
#
# This is essentially the same as the user based matrix you saw constructed in the previous lesson, but for items versus other items. From this, you'll then select the most similar items in order to produce a recommendation suitable for the bottom of a product page.

# %%
book_ratings = books.pivot(index='source', columns='target', values='weight')
book_ratings.head()
# Out:
# MemoryErrorTraceback (most recent call last)
# <ipython-input-12-847f5d274425> in <module>()
# ----> 1 book_ratings = books.pivot(index='source', columns='target', values='weight')
#       2 book_ratings.head()
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    5192         """
#    5193         from pandas.core.reshape.reshape import pivot
# -> 5194         return pivot(self, index=index, columns=columns, values=values)
#    5195
#    5196     _shared_docs['pivot_table'] = """
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in pivot(self, index, columns, values)
#     413             indexed = self._constructor_sliced(self[values].values,
#     414                                                index=index)
# --> 415     return indexed.unstack(columns)
#     416
#     417
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py in unstack(self, level, fill_value)
#    2897         """
#    2898         from pandas.core.reshape.reshape import unstack
# -> 2899         return unstack(self, level, fill_value)
#    2900
#    2901     # ----------------------------------------------------------------------
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value)
#     499         unstacker = _Unstacker(obj.values, obj.index, level=level,
#     500                                fill_value=fill_value,
# --> 501                                constructor=obj._constructor_expanddim)
#     502         return unstacker.get_result()
#     503
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in __init__(self, values, index, level, value_columns, fill_value, constructor)
#     135
#     136         self._make_sorted_values_labels()
# --> 137         self._make_selectors()
#     138
#     139     def _make_sorted_values_labels(self):
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in _make_selectors(self)
#     169
#     170         selector = self.sorted_labels[-1] + stride * comp_index + self.lift
# --> 171         mask = np.zeros(np.prod(self.full_shape), dtype=bool)
#     172         mask.put(selector, True)
#     173
#
# MemoryError:

# %%
item_matrix = []
for i, row in enumerate(books.index):
    b1 = books['source'][row]
    b2 = books['target'][row]
    b_distances = [entry[i] for entry in item_matrix]
    d = books['weight'][row]
    b_distances.append(d)

# %%
#Your code here

# %% [markdown]
# ## Select Books to Test Your Recommender On
#
# Select a small subset of books that you are interested in generating recommendations for.

# %%
#Your code here

# %% [markdown]
# ## Generate Recommendations for a Few Books of Choice
#
# Now that you have the preprocessed and transformed the data, it's time to employ collaborative filtering to generate recommendations! Be sure to print the book name that you are generating recommendations for as well as the name of the books being recommended.

# %%
#Your code here

# %% [markdown]
# ## Summary
#
# Well done! In this lab, you effectively created a recommendation system for a real world dataset!
